# %%
import pandas as pd

fea_file = '~/Library/Java/MinimalGeneralization/RuleBasedLearnerEnglishFiles/CELEXPrefixStrip.fea'
encoding = 'latin1' #'cp1252' #'ISO-8859-7'

pd.read_csv(fea_file, sep='\t', encoding=encoding, engine='python')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-28-9c04627d78d5> in <module>
#       4 encoding = 'cp1252' #'ISO-8859-7'
#       5
# ----> 6 pd.read_csv(fea_file, sep='\t', encoding=encoding, engine='python')
#
# ...
